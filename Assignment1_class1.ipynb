# %%
import numpy as np
import matplotlib.pyplot as plt
#import cv2
import pandas as pd
import scipy.io as sc
import sklearn.datasets
# Out:
# /home/ishaan/Softwares/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/ishaan/Softwares/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
print np.__version__
# Out:
#   File "<ipython-input-10-a7732c6d8ad1>", line 1
#     print np.__version__
#            ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(np.__version__)?

# %%
list1=[]
n=0
n=input()
for i in range (n):
    list1.append(input())
list2=[]
m=input()
for i in range (m):
    list2.append(input())
for i in list1:
    for k in list2:
        if (list1[i]==list2[k]):
           del list1[i]
print list1
# Out:
# 5
# 1
# 2
# 3
# 4
# 5
# 2
# 5
# 6
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-4c78e311cb15> in <module>()
#      10 for i in list1:
#      11     for k in list2:
# ---> 12         if (list1[i]==list2[k]):
#      13            del list1[i]
#      14 print list1
#
# IndexError: list index out of range

# %%
print list1[0]
# Out:
# 1

# %%
[x for x in list2 for y in list1 if x!=y]
# Out:
# [5, 5, 5, 5, 6, 6, 6, 6, 6]

# %%
[x for x in list1 if x not in list2]
# Out:
# [1, 2, 3, 4]

# %%
some_list=list([1,2,3])

# %%
print some_list
# Out:
# [1, 2, 3]

# %%
some_list=list(1,2,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-fe8932892007> in <module>()
# ----> 1 some_list=list(1,2,3)
#
# TypeError: list() takes at most 1 argument (3 given)

# %%
some_list=list(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-9ba4f5cc2b56> in <module>()
# ----> 1 some_list=list(2)
#
# TypeError: 'int' object is not iterable

# %%
some_list=[1,2,3]

# %%
print some_list
# Out:
# [1, 2, 3]

# %% [markdown]
# import random

# %%
random.random()
# Out:
# 0.6561588395032926

# %%
random.shuffle(some_list)

# %%
print some_list
# Out:
# [1, 3, 2]

# %%
print list
# Out:
# <type 'list'>

# %%
print list
# Out:
# <type 'list'>

# %%
print list1
# Out:
# [1, 2, 3, 4, 5]

# %%
print (list1[-3:])
# Out:
# [3, 4, 5]

# %%
print (list1[-0:])
# Out:
# [1, 2, 3, 4, 5]

# %%
print (list1[3:5])
# Out:
# [4, 5]

# %%
print(list1[-1:])
# Out:
# [5]

# %%
print list1[-1:]
# Out:
# [5]

# %%
print list1[-5:]
# Out:
# [1, 2, 3, 4, 5]

# %%
def extendList(val, list=[]):
 list.append(val)
 return list

list1 = extendList(10)
list2 = extendList(123,[])
list3 = extendList('a')
print "list1 = %s" % list1
print "list2 = %s" % list2
print "list3 = %s" % list3
# Out:
# list1 = [10, 'a']
# list2 = [123]
# list3 = [10, 'a']

# %%
def sort_list(list_ext,n):
    i=1
    for j in range(n):
        for i in range(n-j):
            if(list_ext[i-1]>list_ext[i]):
                temp=[]
                temp=list_ext[i]
                list_ext[i]=list_ext[i-1]
                list_ext[i-1]=temp
            else: 
                continue
    return list_ext
    
#main method
n=input()
list_ext=[]
list_in=[]
input_string=""
for i in range(n):
    input_string=raw_input()
    list_in=input_string.split()
    list_ext.append(list_in)
list_ext=sort_list(list_ext,n)
print list_ext
# Out:
# 3
# hello
# right
# a
# [['hello'], ['right'], ['a']]

# %%
def sort_stringlist(list_ext,n):
    if(n==1):
        return list_ext
    for i in range(n):
        for j in range(1,(n)-i):
            #print "reached inner loop"
            if(list_ext[j]<list_ext[j-1]):
                #print "reached"
                temp=""
                temp=list_ext[j-1]
                list_ext[j-1]=list_ext[j]
                list_ext[j]=temp
            else:
                #print "reached else",i,j
                continue
    return list_ext
            
n=input()
list_ext=[]
for i in range(n):
    input_string=raw_input()
    list_ext.append(input_string)
if(n>0):
    list_ext=sort_stringlist(list_ext,n)
print list_ext
# Out:
# 2
# bat
# cat
# ['bat', 'cat']

# %%
n=input()
for i in range(n):
    #for j in range(1,(n)-i):
        print i
# Out:
# 5
# 0
# 1
# 2
# 3
# 4
